# %%
# Question 1

#importing librararies
import numpy as np
import pandas as pd

# %%
#creating the dataframe

df=pd.DataFrame({
    'name':['Isha','Lakshita','Sukriti','Jyoti','Kiran','Hemkesh','Priyanka'],
    'age':[20,20,20,21,21,24,22],
    'mail_id':['panchalisha007@gmail.com','lakshitasolanki@gmail.com','sukriti11@gmail.com','jyoti005@gmail.com','kiran122@gmail.com','hemkesh_america@yahoo.com','priyankaharidas@gmail.com'],
    'phone_no':[9876543210,9876547890,9768954321,9876543298,8907654090,8790654321,9765432109]
})
print(df)
# Out:
#    age                    mail_id      name    phone_no
# 0   20   panchalisha007@gmail.com      Isha  9876543210
# 1   20  lakshitasolanki@gmail.com  Lakshita  9876547890
# 2   20        sukriti11@gmail.com   Sukriti  9768954321
# 3   21         jyoti005@gmail.com     Jyoti  9876543298
# 4   21         kiran122@gmail.com     Kiran  8907654090
# 5   24  hemkesh_america@yahoo.com   Hemkesh  8790654321
# 6   22  priyankaharidas@gmail.com  Priyanka  9765432109

# %%
# Question 2
#Loadind Dataset
df1 = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")

# %%
# 2- a.) First 5 rows of Dataframe 
print(df1.head(5))
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# 2- b.) First 10 rows of the Dataframe
print(df1.head(10))
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
# 2- c.) finding basic statistics on the particular dataset.
df1.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
#df1.describe(include=['object'])
df1.describe(include='all')
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     4/15/2008  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
# 2- d.) Finding the last 5 rows of the dataframe 
print(df1.tail(5))
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
# 2- e.) Extracting the 2nd column and finding basic statistics on it.
print(df1['Location'])

#df1.describe(include='all')
df1['Location'].describe()
# Out:
# 0      Canberra
# 1      Canberra
# 2      Canberra
# 3      Canberra
# 4      Canberra
# 5      Canberra
# 6      Canberra
# 7      Canberra
# 8      Canberra
# 9      Canberra
# 10     Canberra
# 11     Canberra
# 12     Canberra
# 13     Canberra
# 14     Canberra
# 15     Canberra
# 16     Canberra
# 17     Canberra
# 18     Canberra
# 19     Canberra
# 20     Canberra
# 21     Canberra
# 22     Canberra
# 23     Canberra
# 24     Canberra
# 25     Canberra
# 26     Canberra
# 27     Canberra
# 28     Canberra
# 29     Canberra
#          ...
# 336    Canberra
# 337    Canberra
# 338    Canberra
# 339    Canberra
# 340    Canberra
# 341    Canberra
# 342    Canberra
# 343    Canberra
# 344    Canberra
# 345    Canberra
# 346    Canberra
# 347    Canberra
# 348    Canberra
# 349    Canberra
# 350    Canberra
# 351    Canberra
# 352    Canberra
# 353    Canberra
# 354    Canberra
# 355    Canberra
# 356    Canberra
# 357    Canberra
# 358    Canberra
# 359    Canberra
# ...
