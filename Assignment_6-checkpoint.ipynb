# %%
# Question 1
#Visualisation of Weather Dataset

#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
plt.style.use('classic')
# %matplotlib inline

# %%
#Loadind Dataset
df = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.shape
# Out:
# (366, 24)

# %%
df.columns
# Out:
# Index([u'Date', u'Location', u'MinTemp', u'MaxTemp', u'Rainfall',
#        u'Evaporation', u'Sunshine', u'WindGustDir', u'WindGustSpeed',
#        u'WindDir9am', u'WindDir3pm', u'WindSpeed9am', u'WindSpeed3pm',
#        u'Humidity9am', u'Humidity3pm', u'Pressure9am', u'Pressure3pm',
#        u'Cloud9am', u'Cloud3pm', u'Temp9am', u'Temp3pm', u'RainToday',
#        u'RISK_MM', u'RainTomorrow'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 24 columns):
# Date             366 non-null object
# Location         366 non-null object
# MinTemp          366 non-null float64
# MaxTemp          366 non-null float64
# Rainfall         366 non-null float64
# Evaporation      366 non-null float64
# Sunshine         363 non-null float64
# WindGustDir      363 non-null object
# WindGustSpeed    364 non-null float64
# WindDir9am       335 non-null object
# WindDir3pm       365 non-null object
# WindSpeed9am     359 non-null float64
# WindSpeed3pm     366 non-null int64
# Humidity9am      366 non-null int64
# Humidity3pm      366 non-null int64
# Pressure9am      366 non-null float64
# Pressure3pm      366 non-null float64
# Cloud9am         366 non-null int64
# Cloud3pm         366 non-null int64
# Temp9am          366 non-null float64
# Temp3pm          366 non-null float64
# RainToday        366 non-null object
# ...

# %%
#finding missing values
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df.fillna(df.mean())
print(df)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
df.columns
# Out:
# Index([u'Date', u'Location', u'MinTemp', u'MaxTemp', u'Rainfall',
#        u'Evaporation', u'Sunshine', u'WindGustDir', u'WindGustSpeed',
#        u'WindDir9am', u'WindDir3pm', u'WindSpeed9am', u'WindSpeed3pm',
#        u'Humidity9am', u'Humidity3pm', u'Pressure9am', u'Pressure3pm',
#        u'Cloud9am', u'Cloud3pm', u'Temp9am', u'Temp3pm', u'RainToday',
#        u'RISK_MM', u'RainTomorrow'],
#       dtype='object')

# %%
df.isna
# Out:
# <bound method DataFrame.isna of            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
#Univariate Data Plotting
sns.distplot(df['MinTemp'], hist=True, kde=True, rug=False, color='Teal')
plt.show()

# %%
plt.close()

# %%
plt.subplot(221)
sns.distplot(df['MaxTemp'], color='red')
plt.subplot(222)
sns.distplot(df['MinTemp'], color='green')
plt.show()

# %%
plt.close()

# %%
#Kernel Density Estimation - KDE
sns.kdeplot(df['Humidity3pm'], shade=True, color='yellow')
plt.show()

# %%
plt.close()

# %%
plt.subplot(211)
sns.kdeplot(df['Pressure9am'], bw=100, label='bin, size=100')
plt.legend();
plt.show()

# %%
plt.close()

# %%
#Bivariate Data Plotting
#plotting Scatterplot
sns.jointplot(x='Temp9am', y='Temp3pm', data=df, color='Fuchsia')
plt.show()

# %%
plt.close()

# %%
#KDE for Bivariate Data
sns.jointplot(x=df['Evaporation'], y=df['Sunshine'], kind='hex', color='lime')
plt.show()

# %%
plt.close()

# %%
#Categorical - Stripplot
sns.stripplot(x='MinTemp', y='MaxTemp', data=df)
plt.show()

# %%
plt.close()

# %%
#Distribution of observation within categories
sns.swarmplot(x='Rainfall', y='Sunshine', data=df)
plt.show()

# %%
plt.close()

# %%
sns.countplot(df['Humidity3pm'])
plt.show()

# %%
plt.close()

# %%
plt.subplot(121)
sns.distplot(df['Pressure9am'], color='aqua')
plt.subplot(122)
sns.boxplot(df['Pressure3pm'], color='springgreen')
plt.show()

# %%
plt.close()

# %%
# Contingency Table
pd.crosstab(df['RainToday'], df['Location'])
# Out:
# Location   Canberra
# RainToday
# No              300
# Yes              66

# %%
plt.close()

# %%
# Visualization
sns.countplot(x = 'Location', hue = 'RainToday', data = df)
plt.show()

# %%
plt.close()

# %%
sns.countplot(x = 'Cloud9am', hue = 'Cloud3pm', data = df)
plt.show()

# %%
plt.close()

# %%
sns.countplot(x = 'Temp9am', hue = 'Temp3pm', data = df)
plt.show()

# %%
plt.close()

# %%
sns.lmplot('Sunshine', 'Rainfall', data = df, hue = 'Location', fit_reg = True)
plt.show()

# %%
plt.close()

# %%
numerical = ['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'WindGustSpeed', 'Humidity3pm','Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
categorical = ['Location', 'WindGustDir', 'WindDir9am', 'RainToday', 'RainTomorrow', 'RISK_MM']

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df.describe(include = ['object', 'bool'])
# Out:
#              Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count         366       366         363        335        365       366
# unique        366         1          16         16         16         2
# top     4/15/2008  Canberra          NW         SE         NW        No
# freq            1       366          73         47         61       300
#
#        RainTomorrow
# count           366
# unique            2
# top              No
# freq            300

# %%
df['Rainfall'].value_counts()
# Out:
# 0.0     263
# 0.2      17
# 0.6       6
# 0.8       5
# 0.4       5
# 1.0       4
# 1.8       3
# 5.2       3
# 6.6       3
# 4.8       3
# 3.4       3
# 4.0       3
# 2.0       3
# 1.2       3
# 1.6       2
# 3.6       2
# 16.2      2
# 11.0      2
# 6.4       2
# 3.8       2
# 1.4       2
# 17.4      2
# 3.0       2
# 6.2       1
# 2.6       1
# 7.4       1
# 9.8       1
# 4.4       1
# 10.4      1
# 9.0       1
# 2.2       1
# 4.2       1
# 18.8      1
# 19.8      1
# 7.2       1
# 39.8      1
# 2.8       1
# 12.2      1
# 7.6       1
# 8.2       1
# 13.2      1
# 22.6      1
# 5.4       1
# 25.8      1
# 19.2      1
# 14.4      1
# 16.8      1
# Name: Rainfall, dtype: int64

# %%
# Creating correlation matrix
corr_matrix = df[numerical].corr()
print(corr_matrix)
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  WindGustSpeed  \
# MinTemp        1.000000  0.752471  0.201939     0.649930       0.218020
# MaxTemp        0.752471  1.000000 -0.073560     0.690026       0.109672
# Rainfall       0.201939 -0.073560  1.000000    -0.007293       0.096190
# Evaporation    0.649930  0.690026 -0.007293     1.000000       0.288477
# WindGustSpeed  0.218020  0.109672  0.096190     0.288477       1.000000
# Humidity3pm   -0.040709 -0.533327  0.289013    -0.391780      -0.069439
# Pressure9am   -0.501707 -0.290883 -0.331581    -0.381906      -0.540180
# Pressure3pm   -0.498007 -0.379394 -0.250218    -0.391093      -0.526885
# Cloud9am       0.215776 -0.175730  0.180046    -0.106007      -0.012666
# Cloud3pm       0.118397 -0.135991  0.127792    -0.100045       0.050230
# Temp9am        0.916745  0.870604  0.077299     0.707676       0.256223
# Temp3pm        0.722730  0.989261 -0.087493     0.671632       0.072501
#
# ...

# %%
plt.close()

# %%
sns.heatmap(corr_matrix)

# %%
sns.pairplot(df[categorical])

# %%
x = categorical
y = categorical
z = np.random.rand(20)
plt.scatter(x, y, s=z*1000, color='PaleVioletRed')
plt.show()

# %%
plt.close()
